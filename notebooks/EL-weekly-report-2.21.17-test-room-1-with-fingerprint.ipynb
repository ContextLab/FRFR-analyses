# %% [markdown]
# ## Import libraries

# %%
from __future__ import division

from sqlalchemy import create_engine, MetaData, Table
import json
import math
import re
import csv
from itertools import izip_longest
from collections import Counter

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy.ma as ma

# %matplotlib inline

# %%
db_url = "sqlite:///../data/encoding/participants-test-room1.db"
table_name = 'turkdemo'
data_column_name = 'datastring'

# boilerplace sqlalchemy setup
engine = create_engine(db_url)
metadata = MetaData()
metadata.bind = engine
table = Table(table_name, metadata, autoload=True)

# make a query and loop through
s = table.select()
rows = s.execute()

data = []
for row in rows:
    data.append(row[data_column_name])
    
# Now we have all participant datastrings in a list.
# Let's make it a bit easier to work with:

# parse each participant's datastring as json object
# and take the 'data' sub-object
data = [json.loads(part)['data'] for part in data if part is not None]

# insert uniqueid field into trialdata in case it wasn't added
# in experiment:
for part in data:
    for record in part:
#         print(record)
        if type(record['trialdata']) is list:

            record['trialdata'] = {record['trialdata'][0]:record['trialdata'][1]}
        record['trialdata']['uniqueid'] = record['uniqueid']
        
# flatten nested list so we just have a list of the trialdata recorded
# each time psiturk.recordTrialData(trialdata) was called.
def isNotNumber(s):
    try:
        float(s)
        return False
    except ValueError:
        return True

data = [record['trialdata'] for part in data for record in part]

# filter out fields that we dont want using isNotNumber function
filtered_data = [{k:v for (k,v) in part.items() if isNotNumber(k)} for part in data]
    
# Put all subjects' trial data into a dataframe object from the
# 'pandas' python library: one option among many for analysis
data_frame = pd.DataFrame(filtered_data)

data_frame
# Out:
#       internal_node_id  key_press  listNumber list_words recalled_words  \
# 0              0.0-0.0        NaN         NaN        NaN            NaN
# 1              0.0-0.0        NaN         NaN        NaN            NaN
# 2              0.0-0.0        NaN         NaN        NaN            NaN
# 3              0.0-0.0       32.0         NaN        NaN            NaN
# 4              0.0-1.0       32.0         NaN        NaN            NaN
# 5              0.0-2.0       32.0         NaN        NaN            NaN
# 6              0.0-3.0       -1.0         NaN        NaN            NaN
# 7              0.0-4.0       -1.0         NaN        NaN            NaN
# 8              0.0-5.0       -1.0         NaN        NaN            NaN
# 9              0.0-6.0       32.0         NaN        NaN            NaN
# 10             0.0-7.0       32.0         NaN        NaN            NaN
# 11             0.0-8.0        NaN         NaN        NaN            NaN
# 12     0.0-9.0-0.0-0.0       32.0         NaN        NaN            NaN
# 13     0.0-9.0-0.0-1.0        NaN         NaN        NaN            NaN
# 14            0.0-10.0       32.0         NaN        NaN            NaN
# 15            0.0-11.0       -1.0         0.0        NaN            NaN
# 16            0.0-12.0       -1.0         0.0        NaN            NaN
# 17            0.0-13.0       -1.0         0.0        NaN            NaN
# 18            0.0-14.0       -1.0         0.0        NaN            NaN
# 19            0.0-15.0       -1.0         0.0        NaN            NaN
# 20            0.0-16.0       -1.0         0.0        NaN            NaN
# 21            0.0-17.0       -1.0         0.0        NaN            NaN
# 22            0.0-18.0       -1.0         0.0        NaN            NaN
# 23            0.0-19.0       -1.0         0.0        NaN            NaN
# 24            0.0-20.0       -1.0         0.0        NaN            NaN
# 25            0.0-21.0       -1.0         0.0        NaN            NaN
# 26            0.0-22.0       -1.0         0.0        NaN            NaN
# 27            0.0-23.0       -1.0         0.0        NaN            NaN
# 28            0.0-24.0       -1.0         0.0        NaN            NaN
# 29            0.0-25.0       -1.0         0.0        NaN            NaN
# ...                ...        ...         ...        ...            ...
# 44815        0.0-288.0       -1.0        14.0        NaN            NaN
# 44816        0.0-289.0       -1.0        14.0        NaN            NaN
# 44817        0.0-290.0       -1.0        14.0        NaN            NaN
# 44818        0.0-291.0       -1.0        14.0        NaN            NaN
# 44819        0.0-292.0       -1.0        14.0        NaN            NaN
# 44820        0.0-293.0       -1.0         NaN        NaN            NaN
# 44821        0.0-294.0        NaN        14.0         []             []
# 44822        0.0-294.0        NaN        14.0         []             []
# 44823              NaN        NaN         NaN        NaN            NaN
# 44824        0.0-295.0       86.0         NaN        NaN            NaN
# 44825        0.0-296.0       -1.0        15.0        NaN            NaN
# 44826        0.0-297.0       -1.0        15.0        NaN            NaN
# 44827        0.0-298.0       -1.0        15.0        NaN            NaN
# 44828        0.0-299.0       -1.0        15.0        NaN            NaN
# 44829        0.0-300.0       -1.0        15.0        NaN            NaN
# 44830        0.0-301.0       -1.0        15.0        NaN            NaN
# 44831        0.0-302.0       -1.0        15.0        NaN            NaN
# 44832        0.0-303.0       -1.0        15.0        NaN            NaN
# 44833        0.0-304.0       -1.0        15.0        NaN            NaN
# 44834        0.0-305.0       -1.0        15.0        NaN            NaN
# 44835        0.0-306.0       -1.0        15.0        NaN            NaN
# 44836        0.0-307.0       -1.0        15.0        NaN            NaN
# 44837        0.0-308.0       -1.0        15.0        NaN            NaN
# 44838        0.0-309.0       -1.0        15.0        NaN            NaN
# 44839        0.0-310.0       -1.0        15.0        NaN            NaN
# 44840        0.0-311.0       -1.0        15.0        NaN            NaN
# 44841        0.0-312.0       -1.0         NaN        NaN            NaN
# 44842        0.0-313.0        NaN        15.0         []             []
# 44843        0.0-313.0        NaN        15.0         []             []
# 44844              NaN        NaN         NaN        NaN            NaN
#
#                                 responses       rt           state  \
# 0      {"Q0":"FRFR-092116_0","Q1":"Andy"}  29856.0             NaN
# 1                       {"Q0":"","Q1":""}   1080.0             NaN
# 2      {"Q0":"FRFR-092116_0","Q1":"ANDY"}  24464.0             NaN
# 3                                     NaN   5319.0             NaN
# 4                                     NaN   5577.0             NaN
# 5                                     NaN   1606.0             NaN
# 6                                     NaN     -1.0             NaN
# 7                                     NaN     -1.0             NaN
# 8                                     NaN     -1.0             NaN
# 9                                     NaN  10998.0             NaN
# 10                                    NaN   1864.0             NaN
# 11                                    NaN      NaN             NaN
# 12                                    NaN    788.0             NaN
# 13                                    NaN      NaN             NaN
# 14                                    NaN   1654.0             NaN
# 15                                    NaN     -1.0             NaN
# 16                                    NaN     -1.0             NaN
# 17                                    NaN     -1.0             NaN
# 18                                    NaN     -1.0             NaN
# 19                                    NaN     -1.0             NaN
# 20                                    NaN     -1.0             NaN
# 21                                    NaN     -1.0             NaN
# 22                                    NaN     -1.0             NaN
# 23                                    NaN     -1.0             NaN
# 24                                    NaN     -1.0             NaN
# 25                                    NaN     -1.0             NaN
# 26                                    NaN     -1.0             NaN
# 27                                    NaN     -1.0             NaN
# 28                                    NaN     -1.0             NaN
# 29                                    NaN     -1.0             NaN
# ...                                   ...      ...             ...
# 44815                                 NaN     -1.0             NaN
# 44816                                 NaN     -1.0             NaN
# 44817                                 NaN     -1.0             NaN
# 44818                                 NaN     -1.0             NaN
# 44819                                 NaN     -1.0             NaN
# 44820                                 NaN     -1.0             NaN
# 44821                                 NaN      NaN  strip-features
# 44822                                 NaN      NaN  strip-features
# 44823                                 NaN      NaN             NaN
# 44824                                 NaN   3030.0             NaN
# 44825                                 NaN     -1.0             NaN
# 44826                                 NaN     -1.0             NaN
# 44827                                 NaN     -1.0             NaN
# 44828                                 NaN     -1.0             NaN
# 44829                                 NaN     -1.0             NaN
# 44830                                 NaN     -1.0             NaN
# 44831                                 NaN     -1.0             NaN
# 44832                                 NaN     -1.0             NaN
# 44833                                 NaN     -1.0             NaN
# 44834                                 NaN     -1.0             NaN
# 44835                                 NaN     -1.0             NaN
# 44836                                 NaN     -1.0             NaN
# 44837                                 NaN     -1.0             NaN
# 44838                                 NaN     -1.0             NaN
# 44839                                 NaN     -1.0             NaN
# 44840                                 NaN     -1.0             NaN
# 44841                                 NaN     -1.0             NaN
# 44842                                 NaN      NaN  strip-features
# 44843                                 NaN      NaN  strip-features
# 44844                                 NaN      NaN             NaN
#
#                                                 stimulus  time_elapsed  \
# 0                                                    NaN       29864.0
# 1                                                    NaN        1089.0
# 2                                                    NaN       24472.0
# 3                                                    NaN        5320.0
# 4                                                    NaN       11901.0
# 5                                                    NaN       14511.0
# 6      <p style= 'color:rgb(214,229,18); font-size:5v...       17519.0
# 7      <p style= 'color:rgb(131,169,151); font-size:5...       21524.0
# 8      <p style= 'color:rgb(53,61,86); font-size:5vw;...       25531.0
# 9                                                    NaN       38530.0
# 10                                                   NaN       41399.0
# 11                                                   NaN       42407.0
# 12                                                   NaN       58196.0
# 13                                                   NaN       59201.0
# 14                                                   NaN       75859.0
# 15     <p style= 'color:rgb(187,155,224); font-size:5...       78866.0
# 16     <p style= 'color:rgb(158,169,227); font-size:5...       82871.0
# 17     <p style= 'color:rgb(155,248,149); font-size:5...       86877.0
# 18     <p style= 'color:rgb(3,134,133); font-size:5vw...       90883.0
# 19     <p style= 'color:rgb(179,217,17); font-size:5v...       94887.0
# 20     <p style= 'color:rgb(160,216,161); font-size:5...       98893.0
# 21     <p style= 'color:rgb(176,59,28); font-size:5vw...      102898.0
# 22     <p style= 'color:rgb(237,233,165); font-size:5...      106904.0
# 23     <p style= 'color:rgb(205,136,181); font-size:5...      110909.0
# 24     <p style= 'color:rgb(194,197,72); font-size:5v...      114914.0
# 25     <p style= 'color:rgb(241,251,80); font-size:5v...      118920.0
# 26     <p style= 'color:rgb(117,161,244); font-size:5...      122925.0
# 27     <p style= 'color:rgb(190,14,139); font-size:5v...      126931.0
# 28     <p style= 'color:rgb(154,56,36); font-size:5vw...      130936.0
# 29     <p style= 'color:rgb(224,46,69); font-size:5vw...      134944.0
# ...                                                  ...           ...
# 44815  <p style= 'font-size:5vw; font-family:courier;...     2060951.0
# 44816  <p style= 'font-size:5vw; font-family:courier;...     2064952.0
# 44817  <p style= 'font-size:5vw; font-family:courier;...     2068954.0
# 44818  <p style= 'font-size:5vw; font-family:courier;...     2072956.0
# 44819  <p style= 'font-size:5vw; font-family:courier;...     2076959.0
# 44820  <div class='instructions'><p> When you see the...     2081961.0
# 44821  <p class='mic'><i class='fa fa-microphone blin...     2145387.0
# 44822  <p class='mic'><i class='fa fa-microphone blin...     2145387.0
# 44823                                                NaN           NaN
# 44824                                                NaN     2149426.0
# 44825  <p style= 'font-size:5vw; font-family:courier;...     2152428.0
# 44826  <p style= 'font-size:5vw; font-family:courier;...     2156432.0
# 44827  <p style= 'font-size:5vw; font-family:courier;...     2160434.0
# 44828  <p style= 'font-size:5vw; font-family:courier;...     2164437.0
# 44829  <p style= 'font-size:5vw; font-family:courier;...     2168441.0
# 44830  <p style= 'font-size:5vw; font-family:courier;...     2172443.0
# 44831  <p style= 'font-size:5vw; font-family:courier;...     2176446.0
# 44832  <p style= 'font-size:5vw; font-family:courier;...     2180448.0
# 44833  <p style= 'font-size:5vw; font-family:courier;...     2184452.0
# 44834  <p style= 'font-size:5vw; font-family:courier;...     2188453.0
# 44835  <p style= 'font-size:5vw; font-family:courier;...     2192455.0
# 44836  <p style= 'font-size:5vw; font-family:courier;...     2196458.0
# 44837  <p style= 'font-size:5vw; font-family:courier;...     2200460.0
# 44838  <p style= 'font-size:5vw; font-family:courier;...     2204462.0
# 44839  <p style= 'font-size:5vw; font-family:courier;...     2208464.0
# 44840  <p style= 'font-size:5vw; font-family:courier;...     2212467.0
# 44841  <div class='instructions'><p> When you see the...     2217470.0
# 44842  <p class='mic'><i class='fa fa-microphone blin...     2280905.0
# 44843  <p class='mic'><i class='fa fa-microphone blin...     2280905.0
# 44844                                                NaN           NaN
#
#        trialNumber  trial_index     trial_type                 uniqueid  \
# 0              NaN          0.0    survey-text  debug82SI3M:debugJ7ZQB7
# 1              NaN          0.0    survey-text  debug82SI3M:debugJ7ZQB7
# 2              NaN          0.0    survey-text  debug82SI3M:debugJ7ZQB7
# 3              NaN          0.0           text  debug82SI3M:debugJ7ZQB7
# 4              NaN          1.0           text  debug82SI3M:debugJ7ZQB7
# 5              NaN          2.0           text  debug82SI3M:debugJ7ZQB7
# 6              NaN          3.0    single-stim  debug82SI3M:debugJ7ZQB7
# 7              NaN          4.0    single-stim  debug82SI3M:debugJ7ZQB7
# 8              NaN          5.0    single-stim  debug82SI3M:debugJ7ZQB7
# 9              NaN          6.0           text  debug82SI3M:debugJ7ZQB7
# 10             NaN          7.0           text  debug82SI3M:debugJ7ZQB7
# 11             NaN          8.0  call-function  debug82SI3M:debugJ7ZQB7
# 12             NaN          9.0           text  debug82SI3M:debugJ7ZQB7
# 13             NaN         10.0  call-function  debug82SI3M:debugJ7ZQB7
# 14             NaN         11.0           text  debug82SI3M:debugJ7ZQB7
# 15             0.0         12.0    single-stim  debug82SI3M:debugJ7ZQB7
# 16             1.0         13.0    single-stim  debug82SI3M:debugJ7ZQB7
# 17             2.0         14.0    single-stim  debug82SI3M:debugJ7ZQB7
# 18             3.0         15.0    single-stim  debug82SI3M:debugJ7ZQB7
# 19             4.0         16.0    single-stim  debug82SI3M:debugJ7ZQB7
# 20             5.0         17.0    single-stim  debug82SI3M:debugJ7ZQB7
# 21             6.0         18.0    single-stim  debug82SI3M:debugJ7ZQB7
# 22             7.0         19.0    single-stim  debug82SI3M:debugJ7ZQB7
# 23             8.0         20.0    single-stim  debug82SI3M:debugJ7ZQB7
# 24             9.0         21.0    single-stim  debug82SI3M:debugJ7ZQB7
# 25            10.0         22.0    single-stim  debug82SI3M:debugJ7ZQB7
# 26            11.0         23.0    single-stim  debug82SI3M:debugJ7ZQB7
# 27            12.0         24.0    single-stim  debug82SI3M:debugJ7ZQB7
# 28            13.0         25.0    single-stim  debug82SI3M:debugJ7ZQB7
# 29            14.0         26.0    single-stim  debug82SI3M:debugJ7ZQB7
# ...            ...          ...            ...                      ...
# 44815         11.0        287.0    single-stim  debugCWO54U:debugQ59MF8
# 44816         12.0        288.0    single-stim  debugCWO54U:debugQ59MF8
# 44817         13.0        289.0    single-stim  debugCWO54U:debugQ59MF8
# 44818         14.0        290.0    single-stim  debugCWO54U:debugQ59MF8
# 44819         15.0        291.0    single-stim  debugCWO54U:debugQ59MF8
# 44820          NaN        292.0    single-stim  debugCWO54U:debugQ59MF8
# 44821          NaN        293.0    free-recall  debugCWO54U:debugQ59MF8
# 44822          NaN        293.0    free-recall  debugCWO54U:debugQ59MF8
# 44823          NaN          NaN            NaN  debugCWO54U:debugQ59MF8
# 44824          NaN        294.0           text  debugCWO54U:debugQ59MF8
# 44825          0.0        295.0    single-stim  debugCWO54U:debugQ59MF8
# 44826          1.0        296.0    single-stim  debugCWO54U:debugQ59MF8
# 44827          2.0        297.0    single-stim  debugCWO54U:debugQ59MF8
# 44828          3.0        298.0    single-stim  debugCWO54U:debugQ59MF8
# 44829          4.0        299.0    single-stim  debugCWO54U:debugQ59MF8
# 44830          5.0        300.0    single-stim  debugCWO54U:debugQ59MF8
# 44831          6.0        301.0    single-stim  debugCWO54U:debugQ59MF8
# 44832          7.0        302.0    single-stim  debugCWO54U:debugQ59MF8
# 44833          8.0        303.0    single-stim  debugCWO54U:debugQ59MF8
# 44834          9.0        304.0    single-stim  debugCWO54U:debugQ59MF8
# 44835         10.0        305.0    single-stim  debugCWO54U:debugQ59MF8
# 44836         11.0        306.0    single-stim  debugCWO54U:debugQ59MF8
# 44837         12.0        307.0    single-stim  debugCWO54U:debugQ59MF8
# 44838         13.0        308.0    single-stim  debugCWO54U:debugQ59MF8
# 44839         14.0        309.0    single-stim  debugCWO54U:debugQ59MF8
# 44840         15.0        310.0    single-stim  debugCWO54U:debugQ59MF8
# 44841          NaN        311.0    single-stim  debugCWO54U:debugQ59MF8
# 44842          NaN        312.0    free-recall  debugCWO54U:debugQ59MF8
# 44843          NaN        312.0    free-recall  debugCWO54U:debugQ59MF8
# 44844          NaN          NaN            NaN  debugCWO54U:debugQ59MF8
#
#                                                  weights
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 44815                                                NaN
# 44816                                                NaN
# 44817                                                NaN
# 44818                                                NaN
# 44819                                                NaN
# 44820                                                NaN
# 44821                                                NaN
# 44822                                                NaN
# 44823  {u'category': 0.5, u'color': 0.5, u'location':...
# 44824                                                NaN
# 44825                                                NaN
# 44826                                                NaN
# 44827                                                NaN
# 44828                                                NaN
# 44829                                                NaN
# 44830                                                NaN
# 44831                                                NaN
# 44832                                                NaN
# 44833                                                NaN
# 44834                                                NaN
# 44835                                                NaN
# 44836                                                NaN
# 44837                                                NaN
# 44838                                                NaN
# 44839                                                NaN
# 44840                                                NaN
# 44841                                                NaN
# 44842                                                NaN
# 44843                                                NaN
# 44844  {u'category': 0.5, u'color': 0.5, u'location':...
#
# [44845 rows x 15 columns]

# %%
db_url = "sqlite:///../data/encoding/participants-test-room1.db"
table_name = 'turkdemo'
data_column_name = 'codeversion'

# boilerplace sqlalchemy setup
engine = create_engine(db_url)
metadata = MetaData()
metadata.bind = engine
table = Table(table_name, metadata, autoload=True)

# make a query and loop through
s = table.select()
rows = s.execute()

versions = []
version_dict = {}
for row in rows:
    version_dict[row[0]]=row[data_column_name]

    
version_col = []
for idx,sub in enumerate(data_frame['uniqueid'].unique()):
    for i in range(sum(data_frame['uniqueid']==sub)):
        version_col.append(version_dict[sub])
data_frame['exp_version']=version_col

# data_frame

# %%
# read in stimulus library
wordpool = pd.read_csv('../stimuli/cut_wordpool.csv')

# %%
# this function takes the data frame and returns subject specific data based on the subid variable
def filterData(data_frame,subid):
    filtered_stim_data = data_frame[data_frame['stimulus'].notnull() & data_frame['listNumber'].notnull()]
    filtered_stim_data = filtered_stim_data[filtered_stim_data['trial_type']=='single-stim']
    filtered_stim_data =  filtered_stim_data[filtered_stim_data['uniqueid']==subid]
    return filtered_stim_data

# this function parses the data creating an array of dictionaries, where each dictionary represents a trial (word presented) along with the stimulus attributes
def createStimDict(data):
    stimDict = []
    for index, row in data.iterrows():
        stimDict.append({
                'text': str(re.findall('>(.+)<',row['stimulus'])[0]),
                'color' : { 'r' : int(re.findall('rgb\((.+)\)',row['stimulus'])[0].split(',')[0]),
                           'g' : int(re.findall('rgb\((.+)\)',row['stimulus'])[0].split(',')[1]),
                           'b' : int(re.findall('rgb\((.+)\)',row['stimulus'])[0].split(',')[2])
                           },
                'location' : {
                    'top': float(re.findall('top:(.+)\%;', row['stimulus'])[0]),
                    'left' : float(re.findall('left:(.+)\%', row['stimulus'])[0])
                    },
                'category' : wordpool['CATEGORY'].iloc[list(wordpool['WORD'].values).index(str(re.findall('>(.+)<',row['stimulus'])[0]))],
                'size' : wordpool['SIZE'].iloc[list(wordpool['WORD'].values).index(str(re.findall('>(.+)<',row['stimulus'])[0]))],
                'wordLength' : len(str(re.findall('>(.+)<',row['stimulus'])[0])),
                'firstLetter' : str(re.findall('>(.+)<',row['stimulus'])[0])[0],
                'listnum' : row['listNumber']
            })
    return stimDict

# this function loads in the recall data into an array of arrays, where each array represents a list of words
def loadRecallData(subid):
    recalledWords = []
    for i in range(0,16):
        try:
            f = open('../data/recall/room1/' + subid + '/' + subid + '-' + str(i) + '.wav.txt', 'rb')
            spamreader = csv.reader(f, delimiter=' ', quotechar='|')
        except (IOError, OSError) as e:
            print(e)
        for row in spamreader:
            recalledWords.append(row[0].split(','))
    return recalledWords

# this function computes accuracy for a series of lists
def computeListAcc(stimDict,recalledWords):
    accVec = []
    for i in range(0,16):
        stim = [stim['text'] for stim in stimDict if stim['listnum']==i]
        recalled= recalledWords[i]
        
        acc = 0
        tmpstim = stim[:]
        for word in recalled:
            if word in tmpstim:
                tmpstim.remove(word)
                acc+=1
        accVec.append(acc/len(stim))
    return accVec

# %%
# subjects who have completed the exp
subids = list(data_frame[data_frame['listNumber']==15]['uniqueid'].unique())
#print(len(subids))
#print(subids)

# print(data_frame)

subids.remove('debugAD2211:debugB3TKJQ') # this was Andy testing all the way through
subids.remove('debug7XDZDR:debugO8OCCV') # another test
subids.remove('debugTX7U35:debugZFTPLT') # another test - allison
subids.remove('debugCWO54U:debugQ59MF8')

pres_data = []
pres = []
rec = []


pres_exp1 = []
rec_exp1 = []
pres_exp2 = []
rec_exp2 = []
pres_exp3 = []
rec_exp3 = []
pres_exp4 = []
rec_exp4 = []
pres_exp5 = []
rec_exp5 = []

pres_all = []
rec_all = []

uniqueID_1 = []

# for each subject that completed the experiment
for idx,sub in enumerate(subids):
    
    print('Running analysis for subject: ', sub)    
        
    # get the subjects data
    filteredStimData = filterData(data_frame,sub)
    
    # parse the subjects data
    stimDict = createStimDict(filteredStimData)
    sub_data = pd.DataFrame(stimDict)
    sub_data['subject']=idx
    sub_data['experiment']=filteredStimData['exp_version'].values[0]
    sub_data = sub_data[['experiment','subject','listnum','text','category','color','location','firstLetter','size','wordLength']]
    
    pres_data.append(sub_data)
    pres.append([list(sub_data[sub_data['listnum']==lst]['text'].values) for lst in sub_data['listnum'].unique()])
    
    # load in the recall data
    recalledWords = loadRecallData(sub)
    rec.append(recalledWords)
    
    if filteredStimData['exp_version'].values[0]=='0.0':
        pres_exp1.append([list(sub_data[sub_data['listnum']==lst]['text'].values) for lst in sub_data['listnum'].unique()])
        rec_exp1.append(recalledWords)
        uniqueID_1.append(filteredStimData['uniqueid'].values[0])
        
    if filteredStimData['exp_version'].values[0]=='1.0':
        pres_exp1.append([list(sub_data[sub_data['listnum']==lst]['text'].values) for lst in sub_data['listnum'].unique()])
        rec_exp1.append(recalledWords)
        uniqueID_1.append(filteredStimData['uniqueid'].values[0])
        
    if filteredStimData['exp_version'].values[0]=='1.1':
        pres_exp1.append([list(sub_data[sub_data['listnum']==lst]['text'].values) for lst in sub_data['listnum'].unique()])
        rec_exp1.append(recalledWords)
        uniqueID_1.append(filteredStimData['uniqueid'].values[0])
        
    if filteredStimData['exp_version'].values[0]=='2.1':
        pres_exp2.append([list(sub_data[sub_data['listnum']==lst]['text'].values) for lst in sub_data['listnum'].unique()])
        rec_exp2.append(recalledWords)
        
    if filteredStimData['exp_version'].values[0]=='3.2':
        pres_exp3.append([list(sub_data[sub_data['listnum']==lst]['text'].values) for lst in sub_data['listnum'].unique()])
        rec_exp3.append(recalledWords)
        
    if filteredStimData['exp_version'].values[0]=='4.1':
        pres_exp4.append([list(sub_data[sub_data['listnum']==lst]['text'].values) for lst in sub_data['listnum'].unique()])
        rec_exp4.append(recalledWords)
        
    if filteredStimData['exp_version'].values[0]=='5.1':
        pres_exp5.append([list(sub_data[sub_data['listnum']==lst]['text'].values) for lst in sub_data['listnum'].unique()])
        rec_exp5.append(recalledWords)
        
    experiments = ['0.0', '1.0', '1.1', '2.1', '3.2', '4.1', '5.1']     
        
    if filteredStimData['exp_version'].values[0] in experiments:
        pres_all.append([list(sub_data[sub_data['listnum']==lst]['text'].values) for lst in sub_data['listnum'].unique()])
        rec_all.append(recalledWords)
        
        
pres_data = pd.concat(pres_data)


# print(sub_data)

filteredStimData
# Out:
# ('Running analysis for subject: ', u'debugIAU8V9:debugT1DECK')
# ('Running analysis for subject: ', u'debug02E4FI:debugF7UOXH')
# ('Running analysis for subject: ', u'debugGPNALW:debugXSJ1FD')
# ('Running analysis for subject: ', u'debugS4GATI:debug2LRP6X')
# ('Running analysis for subject: ', u'debugJAPX2W:debugFZOLSG')
# ('Running analysis for subject: ', u'debugA98B98:debug5H8QRL')
# ('Running analysis for subject: ', u'debugKDM8HT:debugH2I05W')
# ('Running analysis for subject: ', u'debugQS9870:debugKM1SRC')
# ('Running analysis for subject: ', u'debugHP65NS:debugLWS9KB')
# ('Running analysis for subject: ', u'debugVFPD79:debugIP75FV')
# ('Running analysis for subject: ', u'debugX84L2K:debugCDN40O')
# ('Running analysis for subject: ', u'debugSU1T93:debugKCB9VM')
# ('Running analysis for subject: ', u'debugE1CAO3:debugONZ2R5')
# ('Running analysis for subject: ', u'debug8DEMRS:debugC55CO6')
# ('Running analysis for subject: ', u'debugKUWU41:debug9FG9EP')
# ('Running analysis for subject: ', u'debugXUZA8U:debugMR3K3X')
# ('Running analysis for subject: ', u'debugGXQACE:debug6WANP0')
# ('Running analysis for subject: ', u'debugN8TPWO:debugF1XWCH')
# ('Running analysis for subject: ', u'debugZQ55YL:debug5WQHPC')
# ('Running analysis for subject: ', u'debugWF2JFB:debugPNRZFQ')
# ('Running analysis for subject: ', u'debugLXMXTP:debugJAXRZL')
# ('Running analysis for subject: ', u'debugD7W6B2:debugFXJC2D')
# ('Running analysis for subject: ', u'debugJW0UKY:debugG9NCA3')
# ('Running analysis for subject: ', u'debugZ0R9XO:debugPR1BCU')
# ('Running analysis for subject: ', u'debugOSJ8VK:debugAN4K2P')
# ('Running analysis for subject: ', u'debugS4IOEN:debug2DXYL2')
# ('Running analysis for subject: ', u'debug1IV91N:debug9XYL8U')
# ('Running analysis for subject: ', u'debugQGWAN9:debugIZ3EEH')
# ('Running analysis for subject: ', u'debugTO82DJ:debugAFPD68')
# ('Running analysis for subject: ', u'debugP9ZZV8:debugTQS2ET')
# ('Running analysis for subject: ', u'debugIAC223:debugU27P0M')
# ('Running analysis for subject: ', u'debug72V1YB:debugKXB44A')
# ('Running analysis for subject: ', u'debugM3UCH0:debugPZOIEH')
# ('Running analysis for subject: ', u'debugL0WVCS:debugM69DK2')
# ('Running analysis for subject: ', u'debugBYLJFW:debug22UWH3')
# ('Running analysis for subject: ', u'debugXS5NY4:debugY34BQO')
# ('Running analysis for subject: ', u'debugO6L2A9:debug84E3ZH')
# ('Running analysis for subject: ', u'debugXZFSOL:debugGZO1LC')
# ('Running analysis for subject: ', u'debug452SO3:debugDAMR1K')
# ('Running analysis for subject: ', u'debugCPJM4F:debugTI4WNA')
# ('Running analysis for subject: ', u'debugSPWUNX:debugM81OMK')
# ('Running analysis for subject: ', u'debugQRX0V3:debugFIWAG8')
# ('Running analysis for subject: ', u'debugS068LA:debug13DB31')
# ('Running analysis for subject: ', u'debugC3RAEJ:debug6CIGS3')
# ('Running analysis for subject: ', u'debugNH00QT:debug4HO8I7')
# ('Running analysis for subject: ', u'debug3EM72R:debug2XMMZ4')
# ('Running analysis for subject: ', u'debugWENFQN:debugX7UL7E')
# ('Running analysis for subject: ', u'debugFIWPXY:debug7EA9DY')
# ('Running analysis for subject: ', u'debug5D6OTU:debug5IX43U')
# ('Running analysis for subject: ', u'debugHJJW7X:debugOWPA1K')
# ('Running analysis for subject: ', u'debugS2SFTI:debugY6QU8Y')
# ('Running analysis for subject: ', u'debug8VJSF7:debugWUNGRP')
# ('Running analysis for subject: ', u'debug6RNZMI:debug2J8S0J')
# ('Running analysis for subject: ', u'debugFW3HQS:debugADVZGD')
# ('Running analysis for subject: ', u'debugY5PWIV:debugU0LN1B')
# ('Running analysis for subject: ', u'debug4PXFJG:debug3V9BT9')
# ('Running analysis for subject: ', u'debugV26ZW3:debugVLLIDM')
# ('Running analysis for subject: ', u'debugSFSSC1:debugCR446Z')
# ('Running analysis for subject: ', u'debug63UB0M:debug16XRDN')
# ('Running analysis for subject: ', u'debugWWIRD6:debugWTEHIK')
# ('Running analysis for subject: ', u'debugSMRL3M:debug2T9X4B')
# ('Running analysis for subject: ', u'debugODOIPY:debug6ONPWV')
# ('Running analysis for subject: ', u'debug6ORWM7:debug7ADT3H')
# ('Running analysis for subject: ', u'debugW6SI9R:debugWV03M1')
# ('Running analysis for subject: ', u'debugY7YP43:debugYO0IUE')
# ('Running analysis for subject: ', u'debugCBO3BC:debug2NEZI7')
# ('Running analysis for subject: ', u'debug6H0A5B:debug86K2S5')
# ('Running analysis for subject: ', u'debugL7TYIX:debugNLXH66')
# ('Running analysis for subject: ', u'debugDHGW09:debugZK16M8')
# ('Running analysis for subject: ', u'debug6JWWQP:debug1PAP9J')
# ('Running analysis for subject: ', u'debug89146R:debugDPAAK7')
# ('Running analysis for subject: ', u'debugL377FE:debugO8QXQG')
# ('Running analysis for subject: ', u'debugCZCEUL:debugD04UT7')
# ('Running analysis for subject: ', u'debugEBAV9E:debug29C17R')
# ('Running analysis for subject: ', u'debugI61UA8:debugV4RSRR')
# ('Running analysis for subject: ', u'debugXIGPXH:debugJOER6P')
# ('Running analysis for subject: ', u'debugEVJKDX:debugY20ZLX')
# ('Running analysis for subject: ', u'debugXG82XV:debug7XPXQA')
# ('Running analysis for subject: ', u'debug8F0O3Y:debug1Q7PWS')
# ('Running analysis for subject: ', u'debug0XNK1W:debugKCW9JG')
# ('Running analysis for subject: ', u'debugNICM6S:debug0JB058')
# ('Running analysis for subject: ', u'debug041A8A:debugIQIAAQ')
# ('Running analysis for subject: ', u'debugAV8EGG:debug6EPUSI')
# ('Running analysis for subject: ', u'debugV6SASQ:debugW3B3VP')
# ('Running analysis for subject: ', u'debugP7VUOP:debugB8JL92')
# ('Running analysis for subject: ', u'debug9FV2TF:debugWO3MDI')
# ('Running analysis for subject: ', u'debugDVMT62:debugG742LL')
# ('Running analysis for subject: ', u'debugUI1RGX:debugLOANIA')
# ('Running analysis for subject: ', u'debugH14OKM:debugFJVFOY')
# ('Running analysis for subject: ', u'debug15RSW5:debugSG1PVV')
# ('Running analysis for subject: ', u'debugR63B0M:debugO5ZN0S')
# ('Running analysis for subject: ', u'debugWEKNUN:debugF8D3AU')
# ('Running analysis for subject: ', u'debug6WWJET:debug901V23')
# ('Running analysis for subject: ', u'debugGJ4XW4:debugVGY2S3')
# ('Running analysis for subject: ', u'debugISDOR1:debugFZWYDB')
# ('Running analysis for subject: ', u'debugRBMLP1:debugF7KBO0')
# ('Running analysis for subject: ', u'debugLNLM16:debugOHGR4D')
# ('Running analysis for subject: ', u'debugLAPBBP:debugD7HYHA')
# ('Running analysis for subject: ', u'debugT500Q9:debugLZ6NLM')
# ('Running analysis for subject: ', u'debugW8KSRX:debugV5HO0Z')
# ('Running analysis for subject: ', u'debugRTVU1S:debugJLNM7Z')
# ('Running analysis for subject: ', u'debugIUTGWZ:debugVE8WVO')
# ('Running analysis for subject: ', u'debugK49M69:debugN87K7J')
# ('Running analysis for subject: ', u'debug1YLZD6:debugVKD9J5')
# ('Running analysis for subject: ', u'debugZXK9YX:debug55ERYT')
# ('Running analysis for subject: ', u'debugGEH1H2:debugCOIUJ2')
# ('Running analysis for subject: ', u'debugTFSK4F:debug1RA62U')
# ('Running analysis for subject: ', u'debug8MN33U:debugQFIXDW')
# ('Running analysis for subject: ', u'debugTX3T1H:debugH6BY10')
# ('Running analysis for subject: ', u'debug550OQF:debugA605R7')
# ('Running analysis for subject: ', u'debugTZNXUP:debugN30JDF')
# ('Running analysis for subject: ', u'debugTMOKC2:debugHEBQ6P')
# ('Running analysis for subject: ', u'debug9OIYL4:debugIQRZNJ')
# ('Running analysis for subject: ', u'debugI3X6EP:debug60WVZJ')
# ('Running analysis for subject: ', u'debugTS3MPL:debugQJA69N')
# ('Running analysis for subject: ', u'debugRN045O:debug4DRLQA')
# ('Running analysis for subject: ', u'debug9HTVZC:debug5T1SWT')
# ('Running analysis for subject: ', u'debugITZQ38:debugI8NKEE')
# ('Running analysis for subject: ', u'debugPD79CR:debugQLQJ9F')
# ('Running analysis for subject: ', u'debugYC9MZ3:debug5WOTDH')
#       internal_node_id  key_press  listNumber list_words recalled_words  \
# 44164         0.0-11.0       -1.0         0.0        NaN            NaN
# 44165         0.0-12.0       -1.0         0.0        NaN            NaN
# 44166         0.0-13.0       -1.0         0.0        NaN            NaN
# 44167         0.0-14.0       -1.0         0.0        NaN            NaN
# 44168         0.0-15.0       -1.0         0.0        NaN            NaN
# 44169         0.0-16.0       -1.0         0.0        NaN            NaN
# 44170         0.0-17.0       -1.0         0.0        NaN            NaN
# 44171         0.0-18.0       -1.0         0.0        NaN            NaN
# 44172         0.0-19.0       -1.0         0.0        NaN            NaN
# 44173         0.0-20.0       -1.0         0.0        NaN            NaN
# 44174         0.0-21.0       -1.0         0.0        NaN            NaN
# 44175         0.0-22.0       -1.0         0.0        NaN            NaN
# 44176         0.0-23.0       -1.0         0.0        NaN            NaN
# 44177         0.0-24.0       -1.0         0.0        NaN            NaN
# 44178         0.0-25.0       -1.0         0.0        NaN            NaN
# 44179         0.0-26.0       -1.0         0.0        NaN            NaN
# 44185         0.0-30.0       -1.0         1.0        NaN            NaN
# 44186         0.0-31.0       -1.0         1.0        NaN            NaN
# 44187         0.0-32.0       -1.0         1.0        NaN            NaN
# 44188         0.0-33.0       -1.0         1.0        NaN            NaN
# 44189         0.0-34.0       -1.0         1.0        NaN            NaN
# 44190         0.0-35.0       -1.0         1.0        NaN            NaN
# 44191         0.0-36.0       -1.0         1.0        NaN            NaN
# 44192         0.0-37.0       -1.0         1.0        NaN            NaN
# 44193         0.0-38.0       -1.0         1.0        NaN            NaN
# 44194         0.0-39.0       -1.0         1.0        NaN            NaN
# 44195         0.0-40.0       -1.0         1.0        NaN            NaN
# 44196         0.0-41.0       -1.0         1.0        NaN            NaN
# 44197         0.0-42.0       -1.0         1.0        NaN            NaN
# 44198         0.0-43.0       -1.0         1.0        NaN            NaN
# ...                ...        ...         ...        ...            ...
# 44460        0.0-279.0       -1.0        14.0        NaN            NaN
# 44461        0.0-280.0       -1.0        14.0        NaN            NaN
# 44462        0.0-281.0       -1.0        14.0        NaN            NaN
# 44463        0.0-282.0       -1.0        14.0        NaN            NaN
# 44464        0.0-283.0       -1.0        14.0        NaN            NaN
# 44465        0.0-284.0       -1.0        14.0        NaN            NaN
# 44466        0.0-285.0       -1.0        14.0        NaN            NaN
# 44467        0.0-286.0       -1.0        14.0        NaN            NaN
# 44468        0.0-287.0       -1.0        14.0        NaN            NaN
# 44469        0.0-288.0       -1.0        14.0        NaN            NaN
# 44470        0.0-289.0       -1.0        14.0        NaN            NaN
# 44471        0.0-290.0       -1.0        14.0        NaN            NaN
# 44472        0.0-291.0       -1.0        14.0        NaN            NaN
# 44473        0.0-292.0       -1.0        14.0        NaN            NaN
# 44479        0.0-296.0       -1.0        15.0        NaN            NaN
# 44480        0.0-297.0       -1.0        15.0        NaN            NaN
# 44481        0.0-298.0       -1.0        15.0        NaN            NaN
# 44482        0.0-299.0       -1.0        15.0        NaN            NaN
# 44483        0.0-300.0       -1.0        15.0        NaN            NaN
# 44484        0.0-301.0       -1.0        15.0        NaN            NaN
# 44485        0.0-302.0       -1.0        15.0        NaN            NaN
# 44486        0.0-303.0       -1.0        15.0        NaN            NaN
# 44487        0.0-304.0       -1.0        15.0        NaN            NaN
# 44488        0.0-305.0       -1.0        15.0        NaN            NaN
# 44489        0.0-306.0       -1.0        15.0        NaN            NaN
# 44490        0.0-307.0       -1.0        15.0        NaN            NaN
# 44491        0.0-308.0       -1.0        15.0        NaN            NaN
# 44492        0.0-309.0       -1.0        15.0        NaN            NaN
# 44493        0.0-310.0       -1.0        15.0        NaN            NaN
# 44494        0.0-311.0       -1.0        15.0        NaN            NaN
#
#       responses   rt state                                           stimulus  \
# 44164       NaN -1.0   NaN  <p style= 'color:rgb(140,254,192); font-size:5...
# 44165       NaN -1.0   NaN  <p style= 'color:rgb(22,234,101); font-size:5v...
# 44166       NaN -1.0   NaN  <p style= 'color:rgb(139,43,111); font-size:5v...
# 44167       NaN -1.0   NaN  <p style= 'color:rgb(254,40,193); font-size:5v...
# 44168       NaN -1.0   NaN  <p style= 'color:rgb(198,80,210); font-size:5v...
# 44169       NaN -1.0   NaN  <p style= 'color:rgb(110,65,156); font-size:5v...
# 44170       NaN -1.0   NaN  <p style= 'color:rgb(226,211,186); font-size:5...
# 44171       NaN -1.0   NaN  <p style= 'color:rgb(23,214,17); font-size:5vw...
# 44172       NaN -1.0   NaN  <p style= 'color:rgb(36,75,19); font-size:5vw;...
# 44173       NaN -1.0   NaN  <p style= 'color:rgb(82,116,40); font-size:5vw...
# 44174       NaN -1.0   NaN  <p style= 'color:rgb(116,200,35); font-size:5v...
# 44175       NaN -1.0   NaN  <p style= 'color:rgb(220,74,1); font-size:5vw;...
# 44176       NaN -1.0   NaN  <p style= 'color:rgb(213,170,51); font-size:5v...
# 44177       NaN -1.0   NaN  <p style= 'color:rgb(0,177,143); font-size:5vw...
# 44178       NaN -1.0   NaN  <p style= 'color:rgb(138,56,172); font-size:5v...
# 44179       NaN -1.0   NaN  <p style= 'color:rgb(92,11,34); font-size:5vw;...
# 44185       NaN -1.0   NaN  <p style= 'color:rgb(64,65,84); font-size:5vw;...
# 44186       NaN -1.0   NaN  <p style= 'color:rgb(56,252,218); font-size:5v...
# 44187       NaN -1.0   NaN  <p style= 'color:rgb(94,77,222); font-size:5vw...
# 44188       NaN -1.0   NaN  <p style= 'color:rgb(125,133,35); font-size:5v...
# 44189       NaN -1.0   NaN  <p style= 'color:rgb(184,153,135); font-size:5...
# 44190       NaN -1.0   NaN  <p style= 'color:rgb(13,180,48); font-size:5vw...
# 44191       NaN -1.0   NaN  <p style= 'color:rgb(53,168,46); font-size:5vw...
# 44192       NaN -1.0   NaN  <p style= 'color:rgb(221,13,39); font-size:5vw...
# 44193       NaN -1.0   NaN  <p style= 'color:rgb(79,51,12); font-size:5vw;...
# 44194       NaN -1.0   NaN  <p style= 'color:rgb(114,220,35); font-size:5v...
# 44195       NaN -1.0   NaN  <p style= 'color:rgb(221,139,131); font-size:5...
# 44196       NaN -1.0   NaN  <p style= 'color:rgb(11,196,174); font-size:5v...
# 44197       NaN -1.0   NaN  <p style= 'color:rgb(18,145,174); font-size:5v...
# 44198       NaN -1.0   NaN  <p style= 'color:rgb(96,82,163); font-size:5vw...
# ...         ...  ...   ...                                                ...
# 44460       NaN -1.0   NaN  <p style= 'color:rgb(70,184,205); font-size:5v...
# 44461       NaN -1.0   NaN  <p style= 'color:rgb(93,106,201); font-size:5v...
# 44462       NaN -1.0   NaN  <p style= 'color:rgb(151,77,253); font-size:5v...
# 44463       NaN -1.0   NaN  <p style= 'color:rgb(117,128,187); font-size:5...
# 44464       NaN -1.0   NaN  <p style= 'color:rgb(236,227,72); font-size:5v...
# 44465       NaN -1.0   NaN  <p style= 'color:rgb(13,118,163); font-size:5v...
# 44466       NaN -1.0   NaN  <p style= 'color:rgb(8,38,98); font-size:5vw; ...
# 44467       NaN -1.0   NaN  <p style= 'color:rgb(189,148,51); font-size:5v...
# 44468       NaN -1.0   NaN  <p style= 'color:rgb(63,156,0); font-size:5vw;...
# 44469       NaN -1.0   NaN  <p style= 'color:rgb(220,240,185); font-size:5...
# 44470       NaN -1.0   NaN  <p style= 'color:rgb(17,125,249); font-size:5v...
# 44471       NaN -1.0   NaN  <p style= 'color:rgb(19,189,96); font-size:5vw...
# 44472       NaN -1.0   NaN  <p style= 'color:rgb(99,197,95); font-size:5vw...
# 44473       NaN -1.0   NaN  <p style= 'color:rgb(72,114,130); font-size:5v...
# 44479       NaN -1.0   NaN  <p style= 'color:rgb(230,16,39); font-size:5vw...
# 44480       NaN -1.0   NaN  <p style= 'color:rgb(41,229,27); font-size:5vw...
# 44481       NaN -1.0   NaN  <p style= 'color:rgb(126,107,132); font-size:5...
# 44482       NaN -1.0   NaN  <p style= 'color:rgb(240,157,226); font-size:5...
# 44483       NaN -1.0   NaN  <p style= 'color:rgb(192,131,38); font-size:5v...
# 44484       NaN -1.0   NaN  <p style= 'color:rgb(190,180,69); font-size:5v...
# 44485       NaN -1.0   NaN  <p style= 'color:rgb(206,248,17); font-size:5v...
# 44486       NaN -1.0   NaN  <p style= 'color:rgb(24,113,30); font-size:5vw...
# 44487       NaN -1.0   NaN  <p style= 'color:rgb(34,244,248); font-size:5v...
# 44488       NaN -1.0   NaN  <p style= 'color:rgb(8,141,225); font-size:5vw...
# 44489       NaN -1.0   NaN  <p style= 'color:rgb(228,224,144); font-size:5...
# 44490       NaN -1.0   NaN  <p style= 'color:rgb(23,111,140); font-size:5v...
# 44491       NaN -1.0   NaN  <p style= 'color:rgb(219,138,106); font-size:5...
# 44492       NaN -1.0   NaN  <p style= 'color:rgb(52,204,64); font-size:5vw...
# 44493       NaN -1.0   NaN  <p style= 'color:rgb(252,249,112); font-size:5...
# 44494       NaN -1.0   NaN  <p style= 'color:rgb(87,53,222); font-size:5vw...
#
#        time_elapsed  trialNumber  trial_index   trial_type  \
# 44164       81943.0          0.0         10.0  single-stim
# 44165       85950.0          1.0         11.0  single-stim
# 44166       89955.0          2.0         12.0  single-stim
# 44167       93961.0          3.0         13.0  single-stim
# 44168       97966.0          4.0         14.0  single-stim
# 44169      101971.0          5.0         15.0  single-stim
# 44170      105977.0          6.0         16.0  single-stim
# 44171      109982.0          7.0         17.0  single-stim
# 44172      113988.0          8.0         18.0  single-stim
# 44173      117993.0          9.0         19.0  single-stim
# 44174      121999.0         10.0         20.0  single-stim
# 44175      126004.0         11.0         21.0  single-stim
# 44176      130012.0         12.0         22.0  single-stim
# 44177      134019.0         13.0         23.0  single-stim
# 44178      138026.0         14.0         24.0  single-stim
# 44179      142031.0         15.0         25.0  single-stim
# 44185      221355.0          0.0         29.0  single-stim
# 44186      225357.0          1.0         30.0  single-stim
# 44187      229359.0          2.0         31.0  single-stim
# 44188      233363.0          3.0         32.0  single-stim
# 44189      237365.0          4.0         33.0  single-stim
# 44190      241367.0          5.0         34.0  single-stim
# 44191      245370.0          6.0         35.0  single-stim
# 44192      249373.0          7.0         36.0  single-stim
# 44193      253376.0          8.0         37.0  single-stim
# 44194      257378.0          9.0         38.0  single-stim
# 44195      261380.0         10.0         39.0  single-stim
# 44196      265384.0         11.0         40.0  single-stim
# 44197      269386.0         12.0         41.0  single-stim
# 44198      273387.0         13.0         42.0  single-stim
# ...             ...          ...          ...          ...
# 44460     2003119.0          2.0        278.0  single-stim
# 44461     2007122.0          3.0        279.0  single-stim
# 44462     2011124.0          4.0        280.0  single-stim
# 44463     2015126.0          5.0        281.0  single-stim
# 44464     2019129.0          6.0        282.0  single-stim
# 44465     2023130.0          7.0        283.0  single-stim
# 44466     2027132.0          8.0        284.0  single-stim
# 44467     2031135.0          9.0        285.0  single-stim
# 44468     2035137.0         10.0        286.0  single-stim
# 44469     2039139.0         11.0        287.0  single-stim
# 44470     2043140.0         12.0        288.0  single-stim
# 44471     2047143.0         13.0        289.0  single-stim
# 44472     2051145.0         14.0        290.0  single-stim
# 44473     2055148.0         15.0        291.0  single-stim
# 44479     2129266.0          0.0        295.0  single-stim
# 44480     2133268.0          1.0        296.0  single-stim
# 44481     2137270.0          2.0        297.0  single-stim
# 44482     2141272.0          3.0        298.0  single-stim
# 44483     2145275.0          4.0        299.0  single-stim
# 44484     2149278.0          5.0        300.0  single-stim
# 44485     2153280.0          6.0        301.0  single-stim
# 44486     2157281.0          7.0        302.0  single-stim
# 44487     2161284.0          8.0        303.0  single-stim
# 44488     2165287.0          9.0        304.0  single-stim
# 44489     2169289.0         10.0        305.0  single-stim
# 44490     2173291.0         11.0        306.0  single-stim
# 44491     2177292.0         12.0        307.0  single-stim
# 44492     2181295.0         13.0        308.0  single-stim
# 44493     2185299.0         14.0        309.0  single-stim
# 44494     2189300.0         15.0        310.0  single-stim
#
#                       uniqueid weights exp_version
# 44164  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44165  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44166  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44167  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44168  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44169  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44170  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44171  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44172  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44173  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44174  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44175  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44176  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44177  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44178  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44179  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44185  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44186  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44187  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44188  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44189  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44190  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44191  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44192  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44193  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44194  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44195  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44196  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44197  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44198  debugYC9MZ3:debug5WOTDH     NaN         5.1
# ...                        ...     ...         ...
# 44460  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44461  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44462  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44463  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44464  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44465  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44466  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44467  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44468  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44469  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44470  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44471  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44472  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44473  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44479  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44480  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44481  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44482  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44483  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44484  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44485  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44486  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44487  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44488  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44489  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44490  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44491  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44492  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44493  debugYC9MZ3:debug5WOTDH     NaN         5.1
# 44494  debugYC9MZ3:debug5WOTDH     NaN         5.1
#
# [256 rows x 16 columns]

# %%
uniqueID_1
# Out:
# [u'debugIAU8V9:debugT1DECK',
#  u'debug02E4FI:debugF7UOXH',
#  u'debugGPNALW:debugXSJ1FD',
#  u'debugS4GATI:debug2LRP6X',
#  u'debugJAPX2W:debugFZOLSG',
#  u'debugA98B98:debug5H8QRL',
#  u'debugKDM8HT:debugH2I05W',
#  u'debugQS9870:debugKM1SRC',
#  u'debugHP65NS:debugLWS9KB',
#  u'debugVFPD79:debugIP75FV',
#  u'debugX84L2K:debugCDN40O',
#  u'debugSU1T93:debugKCB9VM',
#  u'debugE1CAO3:debugONZ2R5',
#  u'debug8DEMRS:debugC55CO6',
#  u'debugKUWU41:debug9FG9EP',
#  u'debugXUZA8U:debugMR3K3X',
#  u'debugN8TPWO:debugF1XWCH',
#  u'debugZQ55YL:debug5WQHPC',
#  u'debugWF2JFB:debugPNRZFQ',
#  u'debugLXMXTP:debugJAXRZL',
#  u'debugQRX0V3:debugFIWAG8']

# %%
len(pres_all) == len(rec_all)
# Out:
# True

# %%
import pyrec as pyr

pyro_all = pyr.Pyro(pres = pres_all, rec = rec_all)
pyro_1 = pyr.Pyro(pres = pres_exp1, rec = rec_exp1)
pyro_2 = pyr.Pyro(pres = pres_exp2, rec = rec_exp2)
pyro_3 = pyr.Pyro(pres = pres_exp3, rec = rec_exp3)
pyro_4 = pyr.Pyro(pres = pres_exp4, rec = rec_exp4)
pyro_5 = pyr.Pyro(pres = pres_exp5, rec = rec_exp5)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-b5dee9a97f32> in <module>()
# ----> 1 import pyrec as pyr
#       2
#       3 pyro_all = pyr.Pyro(pres = pres_all, rec = rec_all)
#       4 pyro_1 = pyr.Pyro(pres = pres_exp1, rec = rec_exp1)
#       5 pyro_2 = pyr.Pyro(pres = pres_exp2, rec = rec_exp2)
#
# ImportError: No module named pyrec

# %%
#filteredStimData

# %% [markdown]
# <h1>Number of Subjects Per Experiment</h1>

# %%
print("experiment 1: ")
print(len(pres_exp1))
print 

print("experiment 2: ")
print(len(pres_exp2))
print

print("experiment 3: ")
print(len(pres_exp3))
print

print("experiment 4: ")
print(len(pres_exp4))
print

print("experiment 5: ")
print(len(pres_exp5))
print

# %% [markdown]
# <h1> SPC Average </h1>

# %%
#AGGREGATE
spc_av = pyr.spc(pyro_all)#, listgroup = ['average']*16) 
pyr.plot(spc_av, plot_type = 'subject', subjgroup = ['exp1']*len(pres_exp1) + ['exp2']*len(pres_exp2) + ['exp3']*len(pres_exp3) + ['exp4']*len(pres_exp4) + ['exp5']*len(pres_exp5))

#INDIVIDUAL
# spc_single = pyr.spc(pyro_1)
# pyr.plot(spc_single)

# %% [markdown]
# <h1>PFR Average </h1>

# %%
#AGGREGATE
pfr_av = pyr.pfr(pyro_all)#, listgroup = ['average']*16) 
pyr.plot(pfr_av, plot_type = 'subject', subjgroup = ['exp1']*len(pres_exp1) + ['exp2']*len(pres_exp2) + ['exp3']*len(pres_exp3) + ['exp4']*len(pres_exp4) + ['exp5']*len(pres_exp5))

#INDIVIDUAL
# pfr_single = pyr.pfr(pyro_1)
# pyr.plot(pfr_single)

# %% [markdown]
# <h1> PLR Average</h1>

# %%
#AGGREGATE
plr_av = pyr.plr(pyro_all)#, listgroup = ['average']*16) 
pyr.plot(plr_av, plot_type = 'subject', subjgroup = ['exp1']*len(pres_exp1) + ['exp2']*len(pres_exp2) + ['exp3']*len(pres_exp3) + ['exp4']*len(pres_exp4) + ['exp5']*len(pres_exp5))
#INDIVIDUAL
# plr_single = pyr.plr(pyro_single)
# pyr.plot(plr_single)

# %% [markdown]
# <h1>Lag CRP, Average</h1>

# %%
#AGGREGATE
lagcrp_av = pyr.lagcrp(pyro_all)#, listgroup = ['average']*16) 
pyr.plot(lagcrp_av, plot_type = 'subject', subjgroup = ['exp1']*len(pres_exp1) + ['exp2']*len(pres_exp2) + ['exp3']*len(pres_exp3) + ['exp4']*len(pres_exp4) + ['exp5']*len(pres_exp5))

#INDIVIDUAL
# lagcrp_single = pyr.lagcrp(pyro_single)
# pyr.plot(lagcrp_single)

# %% [markdown]
# <h1>Serial Position Curve, Early/Late Lists</h1>

# %%
# # spc2_av = pyr.spc(pyro)
# # pyr.plot(spc2_av, plot_type = 'subject', subjgroup = ['exp1']*len(pres_exp1) + ['exp2']*len(pres_exp2) + ['exp3']*len(pres_exp3) + ['exp4']*len(pres_exp4) + ['exp5']*len(pres_exp5))
# #AGGREGATE
# spc_av = pyr.lagcrp(pyro_all)#, listgroup = ['average']*16) 
# pyr.plot(lagcrp_av, plot_type = 'subject', subjgroup = ['exp1']*len(pres_exp1) + ['exp2']*len(pres_exp2) + ['exp3']*len(pres_exp3) + ['exp4']*len(pres_exp4) + ['exp5']*len(pres_exp5))

# # #INDIVIDUAL
# # # spc_single = pyr.spc(pyro_single)
# # pyr.plot(spc_single)

fig = plt.figure()

print('Experiment 1')
spc2 = pyr.spc(pyro_1, listgroup=['early']*8 + ['late']*8)
fig_1 = pyr.plot(spc2)
fig.add_subplot(321)

print('Experiment 2')
spc3 = pyr.spc(pyro_2, listgroup=['early']*8 + ['late']*8)
fig_2 = pyr.plot(spc3)
fig.add_subplot(322)

print('Experiment 3')
spc4 = pyr.spc(pyro_3, listgroup=['early']*8 + ['late']*8)
fig_3 = pyr.plot(spc4)
fig.add_subplot(323)

print('Experiment 4')
spc5 = pyr.spc(pyro_4, listgroup=['early']*8 + ['late']*8)
fig_4 = pyr.plot(spc5)
fig.add_subplot(324)

print('Experiment 5')
spc6 = pyr.spc(pyro_5, listgroup=['early']*8 + ['late']*8)
fig_5 = pyr.plot(spc6)

# %% [markdown]
# <h1>PFR, Early/Late Lists</h1>

# %%
fig = plt.figure()

print('Experiment 1')
pfr2 = pyr.pfr(pyro_1, listgroup=['early']*8 + ['late']*8)
fig_1 = pyr.plot(pfr2)
fig.add_subplot(321)

print('Experiment 2')
pfr3 = pyr.pfr(pyro_2, listgroup=['early']*8 + ['late']*8)
fig_2 = pyr.plot(pfr3)
fig.add_subplot(322)

print('Experiment 3')
pfr4 = pyr.pfr(pyro_3, listgroup=['early']*8 + ['late']*8)
fig_3 = pyr.plot(pfr4)
fig.add_subplot(323)

print('Experiment 4')
pfr5 = pyr.pfr(pyro_4, listgroup=['early']*8 + ['late']*8)
fig_4 = pyr.plot(pfr5)
fig.add_subplot(324)

print('Experiment 5')
pfr6 = pyr.pfr(pyro_5, listgroup=['early']*8 + ['late']*8)
fig_5 = pyr.plot(pfr6)

# %% [markdown]
# <h1>PLR, Early/Late Lists

# %%
fig = plt.figure()

print('Experiment 1')
plr2 = pyr.plr(pyro_1, listgroup=['early']*8 + ['late']*8)
fig_1 = pyr.plot(plr2)
fig.add_subplot(321)

print('Experiment 2')
plr3 = pyr.plr(pyro_2, listgroup=['early']*8 + ['late']*8)
fig_2 = pyr.plot(plr3)
fig.add_subplot(322)

print('Experiment 3')
plr4 = pyr.plr(pyro_3, listgroup=['early']*8 + ['late']*8)
fig_3 = pyr.plot(plr4)
fig.add_subplot(323)

print('Experiment 4')
plr5 = pyr.plr(pyro_4, listgroup=['early']*8 + ['late']*8)
fig_4 = pyr.plot(plr5)
fig.add_subplot(324)

print('Experiment 5')
plr6 = pyr.plr(pyro_5, listgroup=['early']*8 + ['late']*8)
fig_5 = pyr.plot(plr6)

# %% [markdown]
# <h1>Lag CRP, Early/Late Lists

# %%
fig = plt.figure()

print('Experiment 1')
lagcrp2 = pyr.lagcrp(pyro_1, listgroup=['early']*8 + ['late']*8)
fig_1 = pyr.plot(lagcrp2)
fig.add_subplot(321)

print('Experiment 2')
lagcrp3 = pyr.lagcrp(pyro_2, listgroup=['early']*8 + ['late']*8)
fig_2 = pyr.plot(lagcrp3)
fig.add_subplot(322)

print('Experiment 3')
lagcrp4 = pyr.lagcrp(pyro_3, listgroup=['early']*8 + ['late']*8)
fig_3 = pyr.plot(lagcrp4)
fig.add_subplot(323)

print('Experiment 4')
lagcrp5 = pyr.lagcrp(pyro_4, listgroup=['early']*8 + ['late']*8)
fig_4 = pyr.plot(lagcrp5)
fig.add_subplot(324)

print('Experiment 5')
lagcrp6 = pyr.lagcrp(pyro_5, listgroup=['early']*8 + ['late']*8)
fig_5 = pyr.plot(lagcrp6)

# %% [markdown]
# <h1>SPC, by Subject

# %%
# spc = pyr.spc(pyro, listgroup=['average']*16)
# pyr.plot(spc, plot_type='grid')#, subjgroup = ['exp1']*21 + ['exp2']*21 + ['exp3']*22 + ['exp4']*23 + ['exp5']*15 )

# %% [markdown]
# <h1>PFR, by Subject

# %%
# pfr = pyr.pfr(pyro, listgroup=['average']*16)
# pyr.plot(pfr, plot_type='subject')

# %% [markdown]
# <h1>PLR, by Subject</h1>

# %%
# plr = pyr.plr(pyro, listgroup=['average']*16)
# pyr.plot(plr, plot_type='subject')

# %% [markdown]
# <h1>Lag CRP, by Subject

# %%
# lagcrp = pyr.lagcrp(pyro, listgroup=['average']*16)
# ax = pyr.plot(lagcrp, plot_type='subject')

# %% [markdown]
# <h1>Transcription Comparison

# %%
##IMPORTS#######
import os 
import glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
################

ALL_SUBS = []
uniqueID_man = []

for subject in os.listdir('/Users/Student/Documents/github/FRFR-analyses/etc/audio_transcriptions_exp1/')[1:]:
    # for each subject folder (in list of strings)
    
    uniqueID_man.append(subject)

    folder='/Users/Student/Documents/github/FRFR-analyses/etc/audio_transcriptions_exp1/'+subject
    os.chdir(folder)
    # change into that subject dir

    SUB_LISTS = []

    for x in range(0,16):
    
        MAN = []

        manname= '*'+str(x)+'.txt'
        MAN_file = open(glob.glob(manname)[0], "r")
        MAN_contents = MAN_file.read().split()
        for line in MAN_contents:
            MAN.append(line.upper())
            MAN_file.close()
        
        SUB_LISTS.append(MAN)
    
    ALL_SUBS.append(SUB_LISTS)
    
    os.chdir('../')


# pyro_1a = pyr.Pyro(pres = pres_exp1, rec = rec_exp1)
pyro_1m = pyr.Pyro(pres = pres_exp1, rec = ALL_SUBS)

uniqueID_man

# %%
print(uniqueID_1)
print(uniqueID_man)

# for each in uniqueID_man:
#      print([i for i,x in enumerate(uniqueID_1) if x == each[0:23]])
    
switcher = [1, 13, 5, 12, 8, 0, 4, 6, 14, 19, 16, 20, 7, 3, 11, 9, 18, 10, 15, 17]
                     

    

#second uniqueID_1[13]
#third uniqueID_1[5]

# %%
track = 0
count = []
for sub in ALL_SUBS:
    x = len(list(set(rec_exp1[3][0]).intersection(sub[0])))
    #x is length of intersection of first list in auto and first list in manual for each manual subject
    count.append(x)
    track = track + 1
    print(track, x)

pos = [i for i, j in enumerate(count) if j == max(count)]
print(pos)

# %%
for idx,x in enumerate(switcher):
    if x>1:
        switcher[idx] = x-1

# %%
print(switcher)

# %%
ordered_rec = [0] * 20

for idx,each in enumerate(switcher):
    ordered_rec[each] = ALL_SUBS[idx]
    
#pyro_1m = pyr.Pyro(pres = ordered_pres, rec = ALL_SUBS)

# %%
print(ordered_rec[3][0])
print(rec_exp1[4][0])

# %%
new_pres = pres_exp1[0:2] + pres_exp1[3:]
print(len(new_pres)==len(ordered_rec))

# %%
pyro_1m = pyr.Pyro(pres = new_pres, rec = ordered_rec)

# %% [markdown]
# <h1>Compare Curves for Manual and Auto Transcriptions (Exp 1)</h1>

# %% [markdown]
# <h2> Serial Position Curve</h2>

# %%
spc_single1 = pyr.spc(pyro_1m, listgroup = ['average']*16)
plt.title('Manual', fontsize=18)
plt.ylim(0,.7)
pyr.plot(spc_single1)

spc_single2 = pyr.spc(pyro_1, listgroup = ['average']*16)
plt.title('Auto', fontsize=18)
pyr.plot(spc_single2)

# %% [markdown]
# <h2> Probability of First Recall</h2>

# %%
pfr_single = pyr.pfr(pyro_1m, listgroup = ['average']*16)
plt.title('Manual', fontsize=18)
plt.ylim(0,.3)
pyr.plot(pfr_single)

pfr_single = pyr.pfr(pyro_1, listgroup = ['average']*16)
plt.title('Auto', fontsize=18)
plt.ylim(0,.3)
pyr.plot(pfr_single)

# %% [markdown]
# <h2>Probability of Last Recall</h2>

# %%
plr_single = pyr.plr(pyro_1m, listgroup = ['average']*16)
plt.title('Manual', fontsize=18)
plt.ylim(0,.12)
pyr.plot(plr_single)

plr_single = pyr.plr(pyro_1, listgroup = ['average']*16)
plt.title('Auto', fontsize=18)
plt.ylim(0,.12)
pyr.plot(plr_single)

# %% [markdown]
# <h2>Lag CRP</h2>

# %%
lagcrp_single = pyr.lagcrp(pyro_1m, listgroup = ['average']*16)
plt.title('Manual', fontsize=18)
plt.ylim(0,.14)
pyr.plot(lagcrp_single)

lagcrp_single = pyr.lagcrp(pyro_1, listgroup = ['average']*16)
plt.title('Auto', fontsize=18)
plt.ylim(0,.14)
pyr.plot(lagcrp_single)

# %% [markdown]
# # Fingerprint

# %% [markdown]
# # Feature-rich free recall analyses

# %% [markdown]
# ### Load the data into a pandas dataframe

# %%
db_url = "sqlite:///../data/encoding/participants-test-room1.db"
table_name = 'turkdemo'
data_column_name = 'datastring'

# boilerplace sqlalchemy setup
engine = create_engine(db_url)
metadata = MetaData()
metadata.bind = engine
table = Table(table_name, metadata, autoload=True)

# make a query and loop through
s = table.select()
rows = s.execute()

data = []
for row in rows:
    data.append(row[data_column_name])
    
# Now we have all participant datastrings in a list.
# Let's make it a bit easier to work with:

# parse each participant's datastring as json object
# and take the 'data' sub-object
data = [json.loads(part)['data'] for part in data if part is not None]

# insert uniqueid field into trialdata in case it wasn't added
# in experiment:
for part in data:
    for record in part:
#         print(record)
        if type(record['trialdata']) is list:

            record['trialdata'] = {record['trialdata'][0]:record['trialdata'][1]}
        record['trialdata']['uniqueid'] = record['uniqueid']
        
# flatten nested list so we just have a list of the trialdata recorded
# each time psiturk.recordTrialData(trialdata) was called.
def isNotNumber(s):
    try:
        float(s)
        return False
    except ValueError:
        return True

data = [record['trialdata'] for part in data for record in part]

# filter out fields that we dont want using isNotNumber function
filtered_data = [{k:v for (k,v) in part.items() if isNotNumber(k)} for part in data]
    
# Put all subjects' trial data into a dataframe object from the
# 'pandas' python library: one option among many for analysis
data_frame = pd.DataFrame(filtered_data)

# %% [markdown]
# ### Add a column to keep track of experiment version number

# %%
db_url = "sqlite:///../data/encoding/participants-test-room1.db"
table_name = 'turkdemo'
data_column_name = 'codeversion'

# boilerplace sqlalchemy setup
engine = create_engine(db_url)
metadata = MetaData()
metadata.bind = engine
table = Table(table_name, metadata, autoload=True)

# make a query and loop through
s = table.select()
rows = s.execute()

versions = []
for row in rows:
    versions.append(row[data_column_name])
    
version_col = []
for idx,sub in enumerate(data_frame['uniqueid'].unique()):
    for i in range(sum(data_frame['uniqueid']==sub)):
        version_col.append(versions[idx])
data_frame['exp_version']=version_col

#print(data_frame['exp_version'])

# %% [markdown]
# ### Number of subjects in each experiment

# %%
subids = list(data_frame[data_frame['listNumber']==15]['uniqueid'].unique())

d = dict()
for sub in subids:
    key = data_frame[data_frame['uniqueid']==sub]['exp_version'].values[0]
    if key in d:
        d[key] += 1
    else:
        d[key] = 1
print('Here is a count of how many subjects we have in each experiment: ',d)
# Out:
# ('Here is a count of how many subjects we have in each experiment: ', {u'5.1': 23, u'4.1': 24, u'1.1': 16, u'0.0': 2, u'3.2': 21, u'3.1': 14, u'1.0': 3, u'2.1': 21})

# %% [markdown]
# ## List audio files for each experiment

# %%
# subids = list(data_frame[data_frame['listNumber']==15]['uniqueid'].unique())

# d = dict()
# for sub in subids:
#     key = data_frame[data_frame['uniqueid']==sub]['exp_version'].values[0]
#     if key in d:
#         d[key].append(sub)
#     else:
#         d[key]=[sub]


# #reaplce these values with the experiment number
# #three values for the case of experiment 1 only
# #print (d["0.0"], d['1.0'], d['1.1'])

# #exp1=d["0.0"]+d['1.0']+d['1.1']

# exp1 = d['4.1']
# #print(exp1)


# import shutil

# print(d['4.1'][0:6] + d['5.1'][0:6])

# for each in d['4.1'][0:6] + d['5.1'][0:6]:
#     folder='/Users/Student/Documents/github/FRFR-analyses/audio/'+ each

#     shutil.copytree(folder, '/Users/Student/Desktop/forCampbell/'+each)

# %% [markdown]
# ### Read in word pool

# %%
# read in stimulus library
wordpool = pd.read_csv('../stimuli/cut_wordpool.csv')

# %% [markdown]
# ### Define data processing functions

# %%
# this function takes the data frame and returns subject specific data based on the subid variable
def filterData(data_frame,subid):
    filtered_stim_data = data_frame[data_frame['stimulus'].notnull() & data_frame['listNumber'].notnull()]
    filtered_stim_data = filtered_stim_data[filtered_stim_data['trial_type']=='single-stim']
    filtered_stim_data =  filtered_stim_data[filtered_stim_data['uniqueid']==subid]
    return filtered_stim_data

# this function parses the data creating an array of dictionaries, where each dictionary represents a trial (word presented) along with the stimulus attributes
def createStimDict(data):
    stimDict = []
    for index, row in data.iterrows():
        stimDict.append({
                'text': str(re.findall('>(.+)<',row['stimulus'])[0]),
                'color' : { 'r' : int(re.findall('rgb\((.+)\)',row['stimulus'])[0].split(',')[0]),
                           'g' : int(re.findall('rgb\((.+)\)',row['stimulus'])[0].split(',')[1]),
                           'b' : int(re.findall('rgb\((.+)\)',row['stimulus'])[0].split(',')[2])
                           },
                'location' : {
                    'top': float(re.findall('top:(.+)\%;', row['stimulus'])[0]),
                    'left' : float(re.findall('left:(.+)\%', row['stimulus'])[0])
                    },
                'category' : wordpool['CATEGORY'].iloc[list(wordpool['WORD'].values).index(str(re.findall('>(.+)<',row['stimulus'])[0]))],
                'size' : wordpool['SIZE'].iloc[list(wordpool['WORD'].values).index(str(re.findall('>(.+)<',row['stimulus'])[0]))],
                'wordLength' : len(str(re.findall('>(.+)<',row['stimulus'])[0])),
                'firstLetter' : str(re.findall('>(.+)<',row['stimulus'])[0])[0],
                'listnum' : row['listNumber']
            })
    return stimDict

# this function loads in the recall data into an array of arrays, where each array represents a list of words
def loadRecallData(subid):
    recalledWords = []
    for i in range(0,16):
        try:
            f = open('../data/recall/room1/' + subid + '/' + subid + '-' + str(i) + '.wav.txt', 'rb')
            spamreader = csv.reader(f, delimiter=' ', quotechar='|')
        except (IOError, OSError) as e:
            print(e)
        for row in spamreader:
            recalledWords.append(row[0].split(','))
    return recalledWords

# this function computes accuracy for a series of lists
def computeListAcc(stimDict,recalledWords):
    accVec = []
    for i in range(0,16):
        stim = [stim['text'] for stim in stimDict if stim['listnum']==i]
        recalled= recalledWords[i]
        
        acc = 0
        tmpstim = stim[:]
        for word in recalled:
            if word in tmpstim:
                tmpstim.remove(word)
                acc+=1
        accVec.append(acc/len(stim))
    return accVec

# %% [markdown]
# ### Define fingerprint class (this will be moved to an importable module at some point)

# %%
# class that computes the fingerprint based on stimulus features and recall organization

# -*- coding: utf-8 -*-
import math
import numpy as np

class Pyfingerprint(object):
    '''pyfingerprint module'''

    def __init__(self, state=None, features=['category', 'size', 'firstLetter', 'wordLength', 'location', 'color', 'temporal'], weights=None, alpha=4, tau=1, sortby=None):
        self.state = state
        self.features = features
        self.weights = weights
        self.alpha = alpha
        self.tau = tau
        self.sortby = sortby

    #### public functions ####

    # given a stimulus list and recalled words, compute the weights
    def computeWeights(self, currentList, recalledWords):
        currentList = self._computeDistance(currentList)
        return self._computeFeatureWeights(currentList, recalledWords, self.features)

    def updateWeights(self,newWeights):
        if self.weights is not None:
            print('weights exist, updating..')
            for feature in self.weights: 
                self.weights[feature].append(newWeights[feature]);
        else:
            print('new weights..')
            self.weights = {};
            for feature in newWeights:
                self.weights[feature] = [];
                self.weights[feature].append(newWeights[feature]);
        print('weights: ', self.weights)

    def getReorderedList(self,nextList):
        print('Reordering list according to state: ' + str(self.state))
        if self.state == 'feature-based':
            return _featurizeList(nextList)
        elif self.state == 'random':
            return _randomizeList(nextList)
        elif self.state == 'optimal':
            return _optimizeList(nextList)
        elif self.state == 'opposite':
            return _oppositizeList(nextList)
        elif self.state == 'strip-features':
            return _stripFeatures(nextList)
        else:
            print('Warning: No fingerprint state assigned, returning same list..')
            return nextList
        
    #### private functions ####
    
    def _computeDistance(self,stimArray):
        
        # initialize distance dictionary
        for stimulus in stimArray:
            stimulus['distances'] = {}
            for feature in self.features:
                stimulus['distances'][feature] = []
                
        # loop over the lists to create distance matrices
        for i,stimulus1 in enumerate(stimArray):
            for j,stimulus2 in enumerate(stimArray):
                
                # logic for temporal clustering
                stimArray[i]['distances']['temporal'].append({
                        'word' : stimArray[j]['text'],
                        'dist' : abs(i - j)
                    })
                
                # logic for category, need to add if statement if we are using category as a feature
                stimArray[i]['distances']['category'].append({
                        'word' : stimArray[j]['text'],
                        'dist' : int(stimArray[i]['category'] != stimArray[j]['category'])
                    })

                # logic for size
                stimArray[i]['distances']['size'].append({
                    'word': stimArray[j]['text'],
                    'dist': int(stimArray[i]['size'] != stimArray[j]['size'])
                })

                # logic for first letter
                stimArray[i]['distances']['firstLetter'].append({
                    'word': stimArray[j]['text'],
                    'dist': int(stimArray[i]['firstLetter'] != stimArray[j]['firstLetter'])
                })

                # logic for word length
                stimArray[i]['distances']['wordLength'].append({
                    'word': stimArray[j]['text'],
                    'dist': abs(stimArray[i]['wordLength'] - stimArray[j]['wordLength'])
                });

                # logic for color distance
                stimArray[i]['distances']['color'].append({
                    'word': stimArray[j]['text'],
                    'dist': math.sqrt(math.pow(stimArray[i]['color']['r'] - stimArray[j]['color']['r'], 2) + math.pow(stimArray[i]['color']['g'] - stimArray[j]['color']['g'], 2) +
                        math.pow(stimArray[i]['color']['b'] - stimArray[j]['color']['b'], 2))
                });

                # logic for spatial distance
                stimArray[i]['distances']['location'].append({
                    'word': stimArray[j]['text'],
                    'dist': math.sqrt(pow(stimArray[i]['location']['top'] - stimArray[j]['location']['top'], 2) + pow(stimArray[i]['location']['left'] - stimArray[j]['location']['left'], 2))
                })
                
        return stimArray
    
    def _computeFeatureWeights(self,currentList, recalledWords, features):

        # initialize the weights object for just this list
        listWeights = {}
        for feature in self.features:
            listWeights[feature] = []

        # return default list if there is not enough data to compute the fingerprint
        if len(recalledWords) <= 2:
            print('Not enough recalls to compute fingerprint, returning default fingerprint.. (everything is .5)')
            for feature in features:
                listWeights[feature] = .5
            return listWeights
        
        # initialize pastWords list
        pastWords = []

        # finger print analysis
        for i in range(0,len(recalledWords)-1):

            # grab current word
            currentWord = recalledWords[i]

            # grab the next word
            nextWord = recalledWords[i + 1]
            
            # grab the words from the encoding list
            encodingWords = [stimulus['text'] for stimulus in currentList]
            
            # append current word to past words log
            # pastWords.append(currentWord)
            
            # if both recalled words are in the encoding list
            if (currentWord in encodingWords and nextWord in encodingWords) and (currentWord not in pastWords and nextWord not in pastWords): 
                # print(currentWord,nextWord,encodingWords,pastWords)
                

                for feature in features:

                    # get the distance vector for the current word
                    distVec = currentList[encodingWords.index(currentWord)]['distances'][feature]

                    # filter distVec removing the words that have already been analyzed from future calculations
                    filteredDistVec = []
                    for word in distVec:
                        if word['word'] in pastWords:
                            pass
                        else:
                            filteredDistVec.append(word)
                            

                    # sort distWords by distances
                    filteredDistVec = sorted(filteredDistVec, key=lambda item:item['dist'])
                    
                    # compute the category listWeights
                    nextWordIdx = [word['word'] for word in filteredDistVec].index(nextWord)

                    # not sure about this part
                    idxs = []
                    for idx,word in enumerate(filteredDistVec):
                        if filteredDistVec[nextWordIdx]['dist'] == word['dist']:
                            idxs.append(idx)

                    listWeights[feature].append(1 - (sum(idxs)/len(idxs) / len(filteredDistVec)))

                pastWords.append(currentWord)

        for feature in listWeights:
            listWeights[feature] = np.mean(listWeights[feature])

        return listWeights

# %%
# subjects who have completed the exp
subids = list(data_frame[data_frame['listNumber']==15]['uniqueid'].unique())

# issue with this subject - need to look into it further
# subids.remove('debugGPNALW:debugXSJ1FD')
# subids.remove('debug4PXFJG:debug3V9BT9')
subids.remove('debugAD2211:debugB3TKJQ') # this was Andy testing all the way through
subids.remove('debug7XDZDR:debugO8OCCV') # another test
subids.remove('debugTX7U35:debugZFTPLT') # another test - allison
subids.remove('debugCWO54U:debugQ59MF8')

# for each subject that completed the experiment
for idx,sub in enumerate(subids):
    
#     print('Running analysis for subject: ', sub)    
        
    # get the subjects data
    filteredStimData = filterData(data_frame,sub)
    
    # parse the subjects data
    stimDict = createStimDict(filteredStimData)
    
    # load in the recall data
    recalledWords = loadRecallData(sub)
    
    # initialize the fingerprint
    pyfingerprint = Pyfingerprint()
    fingerprints= []
    
    # compute a fingerprint for each list
    for i in range(0,16):
        fingerprints.append(pyfingerprint.computeWeights([stim for stim in stimDict if stim['listnum']==i],recalledWords[i]))
        fingerprints[i]['listNum']=i
    tmp = pd.DataFrame(fingerprints)
    
    # compute accuracy
    accVec = computeListAcc(stimDict,recalledWords)
    
    # organize the data
    tmp['accuracy']=accVec
    tmp['subId']=idx
    tmp['experiment']=filteredStimData['exp_version'].values[0]
    cols = ['experiment','subId','listNum','category','color','firstLetter','location','size','wordLength','temporal','accuracy']
    
    if idx==0:
        fingerprintsDF = tmp[cols]
    else:
        fingerprintsDF = fingerprintsDF.append(tmp[cols],ignore_index=True)

fingerprintsDF['experiment'] = fingerprintsDF['experiment'].replace('0.0','1.1')
# Out:
# /Users/paxtonfitzpatrick/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Not enough recalls to compute fingerprint, returning default fingerprint.. (everything is .5)
# Not enough recalls to compute fingerprint, returning default fingerprint.. (everything is .5)
# Not enough recalls to compute fingerprint, returning default fingerprint.. (everything is .5)
# Not enough recalls to compute fingerprint, returning default fingerprint.. (everything is .5)
# Not enough recalls to compute fingerprint, returning default fingerprint.. (everything is .5)
# Not enough recalls to compute fingerprint, returning default fingerprint.. (everything is .5)
# Not enough recalls to compute fingerprint, returning default fingerprint.. (everything is .5)
# Not enough recalls to compute fingerprint, returning default fingerprint.. (everything is .5)

# %% [markdown]
# <h1>Show Fingerprint

# %%
#fingerprintsDF

# %% [markdown]
# <h1> Reorganize data for seaborn

# %%
newData = []
for index, row in fingerprintsDF.iterrows():
    for feature in ['category','color','firstLetter','location','size','wordLength','temporal']:
        newData.append({
                'experiment': row['experiment'],
                'subId': row['subId'],
                'listNum': row['listNum'],
                'feature': feature,
                'accuracy': row['accuracy'],
                'value': row[feature]
            })
fingerprintsDF2 = pd.DataFrame(newData)

# %% [markdown]
# ### import libraries and config for seaborn and statistical tests

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.stats import ttest_ind as ttest

sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 2.5})
# %matplotlib inline

# %% [markdown]
# <h1>Organize by Experiment

# %%
exp1 = fingerprintsDF2['experiment']=='1.1'
exp2 = fingerprintsDF2['experiment']=='2.1'
exp3 = fingerprintsDF2['experiment']=='3.2'
exp4 = fingerprintsDF2['experiment']=='4.1'
exp5 = fingerprintsDF2['experiment']=='5.1'

firsthalf = fingerprintsDF2['listNum']<=7
secondhalf = fingerprintsDF2['listNum']>7

# %% [markdown]
# <h1>Avg. Accuracy, All Experiments

# %%
plt.figure(figsize=(4, 4))

data = fingerprintsDF2[(exp1 | exp2 | exp3 | exp4 | exp5)]
data = data.groupby(['subId','experiment']).mean().reset_index(level=['experiment'])
ax = sns.swarmplot(y='accuracy',x='experiment', data=data)
plt.ylabel('Proportion of words recalled')
plt.ylim(0,1)
plt.show()

# %%
import scipy.stats as stats

data_stats = [data[data['experiment']==exp]['value'].values for exp in data['experiment'].unique()]
print(stats.f_oneway(data_stats[0],data_stats[1],data_stats[2],data_stats[3],data_stats[4]))
for i1,expa in enumerate(data_stats):
    for i2,expb in enumerate(data_stats):
        print(i1,i2,stats.ttest_ind(expa,expb))
# Out:
# F_onewayResult(statistic=5.2239911080086001, pvalue=0.00073554632763144087)
# (0, 0, Ttest_indResult(statistic=0.0, pvalue=1.0))
# (0, 1, Ttest_indResult(statistic=-3.4865217719238593, pvalue=0.0012786027406593008))
# (0, 2, Ttest_indResult(statistic=-0.43916667801291331, pvalue=0.66290411757884238))
# (0, 3, Ttest_indResult(statistic=-1.2717534805564912, pvalue=0.21139660946529409))
# (0, 4, Ttest_indResult(statistic=0.047652384365002173, pvalue=0.9622566666542296))
# (1, 0, Ttest_indResult(statistic=3.4865217719238593, pvalue=0.0012786027406593008))
# (1, 1, Ttest_indResult(statistic=0.0, pvalue=1.0))
# (1, 2, Ttest_indResult(statistic=3.9585459765593516, pvalue=0.00027831818175549266))
# (1, 3, Ttest_indResult(statistic=2.3442764451222819, pvalue=0.02411693019072279))
# (1, 4, Ttest_indResult(statistic=3.8619831106876243, pvalue=0.00041277376569140862))
# (2, 0, Ttest_indResult(statistic=0.43916667801291331, pvalue=0.66290411757884238))
# (2, 1, Ttest_indResult(statistic=-3.9585459765593516, pvalue=0.00027831818175549266))
# (2, 2, Ttest_indResult(statistic=0.0, pvalue=1.0))
# (2, 3, Ttest_indResult(statistic=-1.1362563054785302, pvalue=0.26214241924013154))
# (2, 4, Ttest_indResult(statistic=0.54200070963556546, pvalue=0.59068218662888639))
# (3, 0, Ttest_indResult(statistic=1.2717534805564912, pvalue=0.21139660946529409))
# (3, 1, Ttest_indResult(statistic=-2.3442764451222819, pvalue=0.02411693019072279))
# (3, 2, Ttest_indResult(statistic=1.1362563054785302, pvalue=0.26214241924013154))
# (3, 3, Ttest_indResult(statistic=0.0, pvalue=1.0))
# (3, 4, Ttest_indResult(statistic=1.4367944484567703, pvalue=0.15875085362776914))
# (4, 0, Ttest_indResult(statistic=-0.047652384365002173, pvalue=0.9622566666542296))
# (4, 1, Ttest_indResult(statistic=-3.8619831106876243, pvalue=0.00041277376569140862))
# (4, 2, Ttest_indResult(statistic=-0.54200070963556546, pvalue=0.59068218662888639))
# (4, 3, Ttest_indResult(statistic=-1.4367944484567703, pvalue=0.15875085362776914))
# (4, 4, Ttest_indResult(statistic=0.0, pvalue=1.0))

# %% [markdown]
# <h1>Avg. Recall, Early vs. Late</h1>

# %%
sns.set_style("whitegrid")
#plt.figure(figsize=(2,2))

#fig,ax = plt.subplot()
firsthalf = fingerprintsDF2['listNum']<=7
data = fingerprintsDF2[(exp1 | exp2 | exp3 | exp4 | exp5) & firsthalf].groupby(['subId','experiment']).mean().reset_index(level=['experiment'])
ax = sns.barplot(y='accuracy',x='experiment', data=data)
plt.ylabel('Proportion of words recalled')
plt.ylim(0,1)
ax.set_title('First 8 Lists')
plt.show()

secondhalf = fingerprintsDF2['listNum']>7
data = fingerprintsDF2[(exp1 | exp2 | exp3 | exp4 | exp5) & secondhalf].groupby(['subId','experiment']).mean().reset_index(level=['experiment'])
ax2 = sns.barplot(y='accuracy',x='experiment', data=data)
ax2.set_title('Second 8 Lists')
plt.ylabel('Proportion of words recalled')
plt.ylim(0,1)
plt.show()

# data_stats = [data[data['experiment']==exp and data['listNum']<=7]['value'].values for exp in data['experiment'].unique()]
# print(stats.f_oneway(data_stats[0],data_stats[1],data_stats[2],data_stats[3],data_stats[4]))
# for i1,expa in enumerate(data_stats):
#     for i2,expb in enumerate(data_stats):
#         print(i1,i2,stats.ttest_ind(expa,expb))

# %% [markdown]
# <h1> Avg. Fingerprint, All Experiments

# %%
import scipy.stats as stats

sns.set_style("whitegrid")
plt.figure(figsize=(12,3))

firsthalf = fingerprintsDF2['listNum']<=7
secondhalf = fingerprintsDF2['listNum']>7

data_all = exp1 + exp2 + exp3 + exp4 + exp5

data = fingerprintsDF2[data_all].groupby(['subId','experiment','feature']).mean().reset_index(level=['experiment','feature'])
ax = sns.barplot(hue = 'experiment', y='value', x='feature', data=data,order=['category','color','firstLetter', 'location','size','wordLength','temporal'])
ax.set_title('Average Fingerprint, All Experiments')

sns.set_style("whitegrid")
plt.xticks(rotation='vertical')
plt.legend(loc='top')

#ax.set_position([box.x0,box.y0,box.width*0.9,box.height])
sns.plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
sns.plt.show()


#ANOVA#####

for feature in ['category','color','firstLetter','location','size','wordLength','temporal']:
    
    data1 = data[data['experiment']=='1.1']
    one = data1[data1['feature']==feature]['value'].values
        
    data2 = data[data['experiment']=='2.1']
    two = data2[data2['feature']==feature]['value'].values
    
    data3 = data[data['experiment']=='3.2']
    three = data3[data3['feature']==feature]['value'].values
    
    data4 = data[data['experiment']=='4.1']
    four = data4[data4['feature']==feature]['value'].values
    
    data5 = data[data['experiment']=='5.1']
    five = data5[data5['feature']==feature]['value'].values
    
    
    print(feature)
    print(stats.f_oneway(one, two, three, four, five))
    print()

# # the format you need is a variable for each experiment containing the value of the fingerprint for a given feature for each subject
# data1 = data[data['experiment']=='1.1']
# one = data1[data1['feature']=='category']['value'].values
# Out:
# category
# F_onewayResult(statistic=2.0801679724611581, pvalue=0.089076039799262638)
# ()
# color
# F_onewayResult(statistic=3.2447687417341204, pvalue=0.015141068151841552)
# ()
# firstLetter
# F_onewayResult(statistic=7.6175092000847995, pvalue=2.1559468388670102e-05)
# ()
# location
# F_onewayResult(statistic=0.46463888883815002, pvalue=0.76152486124651675)
# ()
# size
# F_onewayResult(statistic=1.5451843485003516, pvalue=0.19504719878711138)
# ()
# wordLength
# F_onewayResult(statistic=1.8441267902447365, pvalue=0.1263942126978202)
# ()
# temporal
# F_onewayResult(statistic=5.6786133874645186, pvalue=0.00037128659290283042)
# ()

# %% [markdown]
# <h1> Avg. Fingerprint, First vs Late (All Exps.)

# %%
import scipy.stats as stats

firsthalf = fingerprintsDF2['listNum']<=7


plt.figure(figsize=(12, 3))
data_all = exp1 + exp2 + exp3 + exp4 + exp5

data = fingerprintsDF2[(exp1 | exp2 | exp3 | exp4 | exp5) & firsthalf].groupby(['subId','experiment','feature']).mean().reset_index(level=['experiment','feature'])
ax = sns.barplot(hue = 'experiment', y='value', x='feature', data=data,order=['category','color','firstLetter', 'location','size','wordLength','temporal'])
ax.set_title('Avg. Fingerprint, All Exps, First Lists')

sns.set_style("whitegrid")
plt.xticks(rotation='vertical')
plt.legend(loc='top')

#ax.set_position([box.x0,box.y0,box.width*0.9,box.height])
sns.plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
sns.plt.show()


plt.figure(figsize=(12, 3))
data_all = exp1 + exp2 + exp3 + exp4 + exp5

data = fingerprintsDF2[(exp1 | exp2 | exp3 | exp4 | exp5) & secondhalf].groupby(['subId','experiment','feature']).mean().reset_index(level=['experiment','feature'])
ax = sns.barplot(hue = 'experiment', y='value', x='feature', data=data,order=['category','color','firstLetter', 'location','size','wordLength','temporal'])
ax.set_title('Avg. Fingerprint, All Exps, Second Lists')

sns.set_style("whitegrid")
plt.xticks(rotation='vertical')
plt.legend(loc='top')

#ax.set_position([box.x0,box.y0,box.width*0.9,box.height])
sns.plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
sns.plt.show()


#ANOVA#####

for feature in ['category','color','firstLetter','location','size','wordLength','temporal']:
    one = list(dict(list(fingerprintsDF.groupby('experiment')[feature]))['1.1'])
    two = list(dict(list(fingerprintsDF.groupby('experiment')[feature]))['2.1'])
    three = list(dict(list(fingerprintsDF.groupby('experiment')[feature]))['3.2'])
    four = list(dict(list(fingerprintsDF.groupby('experiment')[feature]))['4.1'])
    five = list(dict(list(fingerprintsDF.groupby('experiment')[feature]))['5.1'])
    
    print(feature)
    print(stats.f_oneway(one, two, three, four, five))
    print
# Out:
# category
# F_onewayResult(statistic=nan, pvalue=nan)
#
# color
# F_onewayResult(statistic=nan, pvalue=nan)
#
# firstLetter
# F_onewayResult(statistic=nan, pvalue=nan)
#
# location
# F_onewayResult(statistic=nan, pvalue=nan)
#
# size
# F_onewayResult(statistic=nan, pvalue=nan)
#
# wordLength
# F_onewayResult(statistic=nan, pvalue=nan)
#
# temporal
# F_onewayResult(statistic=nan, pvalue=nan)
